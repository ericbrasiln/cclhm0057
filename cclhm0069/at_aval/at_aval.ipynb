# %% [markdown]
# # 📋️ Atividade Avaliativa da disciplina CCLHM0069 - Introdução à História Digital
#
# Disciplina optativa **do curso de [licenciatura em História](http://historia.males.unilab.edu.br/)** do **Instituto de Humanidades e Letras, campus dos Malês, Universidade da Integração Internacional da Lusofonia Afro-brasileira (UNILAB)**
#
# Semestre 2021.1
#
# Professor [_Eric Brasil_](https://ericbrasiln.github.io)
#
# ---
#
# 📅️ **Data para entrega**: 18/02/2021
#
# ⏰ **Carga Horária**: 6h
#
# 📝 **Pontuação**: 10,0 (dez)
#
# 📥 **Entrega via _SIGAA_**
#
# ---
#
# Como atividade avaliativa do curso, o/a discente pode escolhar entre duas opções: **Reflexão Teórica** ou **Análise Metodológica**.
# Cada opção tem seu conjunto de possibilidades.
#
# A ideia é que o/a discentes escolha o tema ou ferramenta que mais tenha interessa, conhecimento, facilidade e produza seu trabalho final.
#
# ## Opção 1: Reflexão Teórica
#
# Cada discente deve escolher uma temática (das listadas abaixo) e produzir uma reflexão crítica que aborde os aspectos teóricos e/ou metodológicos da relação entre a disciplina Histórica e as tecnologias digitais.
#
# ### Temáticas possíveis
#
# 1. **História e Tecnologia:**
# 	- Material da aula sobre o tema [aqui](https://ericbrasiln.github.io/intro-historia-digital/mod1/sem3_ap.html)
# 	- Bibliografia:
# 		- VERASZTO, E. V.; SILVA, D. DA; MIRANDA, N. A.; SIMON, F. O. Tecnologia: buscando uma definição para o conceito. PRISMA.COM, v. 0, n. 8, p. 19–46, 5 abr. 2009. [link](http://ojs.letras.up.pt/index.php/prismacom/article/view/2065)
# 		- SILVEIRA, P. T. DA. A arqueologia de um nome. In: História, técnica e novas mídias: reflexões sobre a história na era digital. Tese de doutorado. Porto Alegre: UFRGS, 2018. pp 28-62 [link](https://lume.ufrgs.br/handle/10183/189249)
#
# 2. **Passado, futuro e presente do digital na História: Fontes, método e análise**
# 	- Material da aula sobre o tema [aqui](https://ericbrasiln.github.io/intro-historia-digital/mod1/sem4_ap.html)
# 	- Bibliografia:
# 		- FORTES, A.; ALVIM, L. G. M. Evidências, códigos e classificações: o ofício do historiador e o mundo digital. Esboços: histórias em contextos globais, v. 27, n. 45, p. 207–227, 19 jun. 2020. [Link](https://periodicos.ufsc.br/index.php/esbocos/article/view/2175-7976.2020.e68270)
# 		- COSTA, Marcella A. F. DA. Tecnologia, temporalidade e história digital: interpelações ao historiador e ao professor de história. Revista Mosaico - Revista de História, v. 8, n. 2, p. 155–163, 15 dez. 2015. [link](http://seer.pucgoias.edu.br/index.php/mosaico/article/view/4428)
#
# 3. **Algoritmos, dataficação da sociedade e o ofício de Historiadores/as: desigualdade, racismo e violências**
# 	- Material da aula sobre o tema [aqui](https://ericbrasiln.github.io/intro-historia-digital/mod3/sem10_ap.html)
# 	- Bibliografia:
# 		- O’NEIL, CATHY. Componentes da bomba. O que é um modelo? In: Algoritmos de Destruição em massa. São Paulo: Editora Rua do Sabão, 2020. pp. 25-50 link(https://github.com/ericbrasiln/intro-historia-digital/blob/bc111c29d3ec6f35221358f5c4af6edcebef524d/cclhm0069/biblio/oneil.pdf)
# 		- NOBLE, Safiya Umoja. Introdução. In: Algoritmos da opressão. São Paulo: Editora Rua do Sabão, 2021. pp. 7-28 [link](https://github.com/ericbrasiln/intro-historia-digital/blob/bc111c29d3ec6f35221358f5c4af6edcebef524d/cclhm0069/biblio/noble.pdf)
#
# ### **<u>Recomendações Gerais</u>**
#
# 1. 💾️ O arquivo deve ser salvo em um dos seguintes foramtos: **.doc**, **.docx** ou **.odt** e enviado via tarefa no **SIGAA**. **NÃO ENVIE A TAREFA EM FORMATO PDF**
# 2. Utilizem a bibliografia de obrigatória nas respostas.
# 3. Os trabalhos devem ter entre 2 e 3 laudas, formatadas com letra tamanho 12, espaçamento 1,5, fonte Times New Roman.
# 4. Não exitem em tirar dúvidas por email ou via Discord (preferencialmente).
# 5. Todos os trabalhos serão submetidos a programa de avaliação de plágio provido pela Unilab. Trabalhos que apresentem plágio serão zerados.
# 6. Acesse a playlist completa de aulas, workshops e tutoriais [aqui](https://youtube.com/playlist?list=PLX52KPH23_mEnLRUFp_LX-avLJMr7bwHh)
#
# ---
#
# ## Opção 2: Análise Metodológica
#
# Cada discente deve escolher uma das ferramentas, aplicativos e recursos apresentadas no curso e elaborar um produto com ela e produzir um relatório sobre seu uso, impactos e limitações para a pesquisa ou ensino de História.
#
# ### Ferramentas, aplicativos e recursos possíveis:
#
# 1. **Hemeroteca Digital Brasileira da Biblioteca Nacional.**
# 	- Resultado: Busca no repositório e relatório registrando os procedimentos utilizados e resultados encontrados
# 	- Material sobre o tema [aqui](https://ericbrasiln.github.io/intro-historia-digital/mod2/sem5_ap.html)
# 2. **Zotero**
# 	- Resultado: Coleção com as referências bibliográficas do curso e relatório sobre sua utilização. Exportar a coleção criada e enviar junto com o relatório.
# 	- Material sobre o tema [aqui](https://ericbrasiln.github.io/intro-historia-digital/mod2/sem6_ap.html)
# 3. **gImageReader**
# 	- Resultado: Realizar o reconhecimento ótico de caracteres de pelo menos um paper, artigo ou página de jornal e produzir relatório sobre seu uso.
# 	- Material sobre o tema [aqui](https://ericbrasiln.github.io/intro-historia-digital/mod2/sem7_ap.html)
# 4. **Voyant Tools**
# 	- Resultado: Analisar algum corpus documental e gerar gráficos variados (pelo menos dois), produzir relatório sobre seu uso. Anexar link para acesso dos resultados.
# 	- Material sobre o tema [aqui](https://ericbrasiln.github.io/intro-historia-digital/mod2/sem9_ap.html)
# 5. **Markdown**
# 	- Resultado: Produzir uma apresentação sobre a disciplina em formato markdown e colocar on-line através do Netlify. Anexar link.
# 	- Material sobre o tema [aqui](https://ericbrasiln.github.io/intro-historia-digital/mod4a/sem11.html)
# 6. **StoryMapJs**
# 	- Resultado: Produzir um mapa interativo e relatório sobre seu uso. Anexar link para o mapa.
# 	- Material sobre o tema [aqui](https://ericbrasiln.github.io/intro-historia-digital/mod4a/sem12.html)
# 8. **Python para pesquisa em História**
# 	- Resultado: Produzir um script em Python que execute funções simples relacionadas ao que foi apresentado  no módulo 4b. Relatório explicando cada etapa do script, suas funções e resultados esperados.
# 	- Material sobre o tema [aqui](https://ericbrasiln.github.io/intro-historia-digital/mod4b/intro.html)
#
# ### **<u>Recomendações Gerais</u>**
#
# 1. 💾️ O arquivo deve ser salvo em um dos seguintes foramtos: **.doc**, **.docx** ou **.odt** e enviado via tarefa no **SIGAA**. **NÃO ENVIE A TAREFA EM FORMATO PDF**
# 2. Os produtos finais devem ser enviados por e-mail, quando não possuírem link de acesso online.
# 3. Os relatórios devem ter entre 1 e 2 laudas, formatadas com letra tamanho 12, espaçamento 1,5, fonte Times New Roman.
# 4. Não exitem em tirar dúvidas por email ou via Discord (preferencialmente).
# 5. Todos os trabalhos serão submetidos a programa de avaliação de plágio provido pela Unilab. Trabalhos que apresentem plágio serão zerados.
# 6. Acesse a playlist completa de aulas, workshops e tutoriais [aqui](https://youtube.com/playlist?list=PLX52KPH23_mEnLRUFp_LX-avLJMr7bwHh)
